# %%
#%ls Data

import pandas
df = pandas.read_excel('house_sample.xlsx')#读取excel文件数据
df.head()
# Out:
#                                标题    建筑面积   总价        户型  朝向      物 业 费  \
# 0    资深经纪上海人：稀缺3房，南北通透采光好，房东急需用钱！  123.50  760  3室2厅0厨2卫  南北  1.5元/平米・月
# 1     未来规划小上海，精装带地暖，养老，亲子，旅游度假一体化   86.00   76  2室2厅1厨1卫  南北    1.8元/・月
# 2      双高铁 不限贷 买一层送一层 送大露台 看房专车接送   90.00   80  3室2厅1厨2卫  南北       暂无资料
# 3      坐拥嘉兴海宁双轨 享受市区配套 现房值得拥有 可落户   90.00   80  2室1厅1厨1卫  南北       暂无资料
# 4  对口明强校区，精装两房税费少，位置安静，媲美园艺新村，随时看   66.61  285  2室1厅1厨1卫   南  0.8元/平米・月
#
#      环比上月          张贴日期  产权性质    装修  楼层
# 0  ↑1.44%  西元2017年4月12日   商品房  豪华装修  低层
# 1  ↑4.08%  西元2017年4月13日   商品房   精装修  中层
# 2  ↓0.01%  西元2017年4月14日   商品房   精装修  高层
# 3  ↓0.01%  西元2017年4月15日   商品房   简装修  中层
# 4  ↓2.62%  西元2017年4月16日  个人产权   中装修  低层

# %%
with open('maoyan.txt','r') as f:
    string=f.read()
# Out:
# '\n<!DOCTYPE html>\n\n<!--[if IE 8]><html class="ie8"><![endif]-->\n<!--[if IE 9]><html class="ie9"><![endif]-->\n<!--[if gt IE 9]><!--><html><!--<![endif]-->\n<head>\n  <title>TOP100榜 - 猫眼电影 - 一网打尽好电影</title>\n  \n  <link rel="dns-prefetch" href="//p0.meituan.net"  />\n  <link rel="dns-prefetch" href="//p1.meituan.net"  />\n  <link rel="dns-prefetch" href="//ms0.meituan.net" />\n  <link rel="dns-prefetch" href="//ms1.meituan.net" />\n  <link rel="dns-prefetch" href="//analytics.meituan.com" />\n  <link rel="dns-prefetch" href="//report.meituan.com" />\n  <link rel="dns-prefetch" href="//frep.meituan.com" />\n\n  \n  <meta charset="utf-8">\n  <meta name="keywords" content="猫眼电影,电影排行榜,热映口碑榜,最受期待榜,国内票房榜,北美票房榜,猫眼TOP100">\n  <meta name="description" content="猫眼电影热门榜单,包括热映口碑榜,最受期待榜,国内票房榜,北美票房榜,猫眼TOP100,多维度为用户进行选片决策">\n  <meta http-equiv="cleartype" content="yes" />\n  <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n  <meta name="renderer" content="webkit" />\n\n  <meta name="Hand
# ...

# %%
import re
pattern=re.compile('<dd.*?title="(.*?)".*?star">(.*?)</p>.*?releasetime">(.*?)</p>.*?integer">(.*?)</i>.*?fraction">(.*?)</i>',re.S)
movies=re.findall(pattern,string)
for movie in movies:
    print(movie[0],movie[1].strip()[3:],movie[2][5:],movie[3]+movie[4])
# Out:
# 霸王别姬 张国荣,张丰毅,巩俐 1993-01-01 9.6
# 肖申克的救赎 蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿 1994-10-14(美国) 9.5
# 罗马假日 格利高里·派克,奥黛丽·赫本,埃迪·艾伯特 1953-09-02(美国) 9.1
# 这个杀手不太冷 让·雷诺,加里·奥德曼,娜塔莉·波特曼 1994-09-14(法国) 9.5
# 教父 马龙·白兰度,阿尔·帕西诺,詹姆斯·肯恩 1972-03-24(美国) 9.3
# 泰坦尼克号 莱昂纳多·迪卡普里奥,凯特·温丝莱特,比利·赞恩 1998-04-03 9.5
# 唐伯虎点秋香 周星驰,巩俐,郑佩佩 1993-07-01(中国香港) 9.2
# 千与千寻 柊瑠美,入野自由,夏木真理 2001-07-20(日本) 9.3
# 魂断蓝桥 费雯·丽,罗伯特·泰勒,露塞尔·沃特森 1940-05-17(美国) 9.2
# 乱世佳人 费雯·丽,克拉克·盖博,奥利维娅·德哈维兰 1939-12-15(美国) 9.1

# %%
#将总价*10000
df['总价']*1000
# Out:
# 0     760000
# 1      76000
# 2      80000
# 3      80000
# 4     285000
# 5     295000
# 6     240000
# 7     410000
# 8     400000
# 9     270000
# 10    300000
# 11    285000
# 12    340000
# 13    355000
# 14    850000
# 15    359000
# 16    360000
# 17    610000
# 18    770000
# 19    220000
# 20    236000
# 21    298000
# 22    325000
# 23    458000
# 25    560000
# 26    650000
# 27    200000
# 28    255000
# 29    450000
# Name: 总价, dtype: int64

# %%
import numpy as np
#求总价列数据的平方根
np.sqrt(df['总价'])
# Out:
# 0     27.568098
# 1      8.717798
# 2      8.944272
# 3      8.944272
# 4     16.881943
# 5     17.175564
# 6     15.491933
# 7     20.248457
# 8     20.000000
# 9     16.431677
# 10    17.320508
# 11    16.881943
# 12    18.439089
# 13    18.841444
# 14    29.154759
# 15    18.947295
# 16    18.973666
# 17    24.698178
# 18    27.748874
# 19    14.832397
# 20    15.362291
# 21    17.262677
# 22    18.027756
# 23    21.400935
# 25    23.664319
# 26    25.495098
# 27    14.142136
# 28    15.968719
# 29    21.213203
# Name: 总价, dtype: float64

# %%
#将‘朝向’与‘户型’两列数据拼接在一起
df['朝向']+df['户型']
# Out:
# 0     南北3室2厅0厨2卫
# 1     南北2室2厅1厨1卫
# 2     南北3室2厅1厨2卫
# 3     南北2室1厅1厨1卫
# 4      南2室1厅1厨1卫
# 5     南北3室1厅1厨1卫
# 6      南2室1厅1厨1卫
# 7      南3室1厅1厨1卫
# 8      南2室2厅1厨1卫
# 9     南北1室1厅1厨1卫
# 10    南北2室1厅1厨1卫
# 11     南1室1厅1厨1卫
# 12    南北1室1厅1厨1卫
# 13    南北2室1厅1厨1卫
# 14    南北3室2厅1厨2卫
# 15     南2室1厅1厨1卫
# 16     南2室1厅1厨1卫
# 17    南北2室2厅1厨1卫
# 18     南3室2厅0厨2卫
# 19     南1室0厅1厨1卫
# 20    南北2室2厅1厨1卫
# 21     南1室2厅1厨1卫
# 22     南1室2厅1厨1卫
# 23    南北3室2厅1厨1卫
# 25    南北3室2厅1厨2卫
# 26     南2室2厅1厨2卫
# 27     南1室1厅1厨1卫
# 28    南北2室1厅1厨1卫
# 29     南2室1厅0厨1卫
# dtype: object

# %%
#求每套房的房价均值（记得要先将总价*10000）
df['总价']*10000/df['建筑面积']
#df.head()
# Out:
# 0     61538.461538
# 1      8837.209302
# 2      8888.888889
# 3      8888.888889
# 4     42786.368413
# 5     40972.222222
# 6     36596.523330
# 7     55896.387185
# 8     54847.113671
# 9     57446.808511
# 10    61791.967044
# 11    64772.727273
# 12    61818.181818
# 13    58196.721311
# 14    73913.043478
# 15    53582.089552
# 16    53731.343284
# 17    68539.325843
# 18    63218.390805
# 19    66666.666667
# 20    33714.285714
# 21    51379.310345
# 22    50000.000000
# 23    38813.559322
# 25    42424.242424
# 26    60185.185185
# 27    52631.578947
# 28    39843.750000
# 29    64377.682403
# dtype: float64

# %%
#以“元”为分界对s进行切分，并获取切分后的第一个字符
s = '1.5元/平米・月'
s.split('元')[0]
# Out:
# '1.5'

# %%
#定义removeDollar函数实现对字符e按‘元’进行切分并获取切分后的第一个字符
def removeDollar(e): 
    return e.split('元')[0]
removeDollar(s)#调用以上函数对s进行应用
# Out:
# '1.5'

# %%
#将函数removeDollar套用到df的物业费列
df['物 业 费'].map(removeDollar)
# Out:
# 0      1.5
# 1      1.8
# 2     暂无资料
# 3     暂无资料
# 4      0.8
# 5      0.6
# 6      0.6
# 7      1.4
# 8     0.55
# 9     暂无资料
# 10     1.4
# 11    暂无资料
# 12     0.7
# 13     0.5
# 14    0.60
# 15     1.2
# 16     1.4
# 17     1.5
# 18     0.7
# 19     1.4
# 20     0.8
# 21    1.65
# 22    1.83
# 23    1.25
# 25    1.85
# 26    2.30
# 27     0.8
# 28    0.95
# 29     0.7
# Name: 物 业 费, dtype: object

# %%
def removeDollar(e):
    return e.split('元')[0]

#将上面函数以匿名函数形式套用到df的物业费列
df['物 业 费'].map(lambda e:e.split('元')[0])
# Out:
# 0      1.5
# 1      1.8
# 2     暂无资料
# 3     暂无资料
# 4      0.8
# 5      0.6
# 6      0.6
# 7      1.4
# 8     0.55
# 9     暂无资料
# 10     1.4
# 11    暂无资料
# 12     0.7
# 13     0.5
# 14    0.60
# 15     1.2
# 16     1.4
# 17     1.5
# 18     0.7
# 19     1.4
# 20     0.8
# 21    1.65
# 22    1.83
# 23    1.25
# 25    1.85
# 26    2.30
# 27     0.8
# 28    0.95
# 29     0.7
# Name: 物 业 费, dtype: object

# %%
def square(e):
    return e * e 
square(2)
# Out:
# 4

# %%
square2 = lambda e: e * e
square2(2)
# Out:
# 4

# %%
df = pandas.DataFrame([
                    [60,70,50],\
                    [80,79,68],\
                    [63,66,82]], columns = ['First', 'Second', 'Third'])
df
# Out:
#    First  Second  Third
# 0     60      70     50
# 1     80      79     68
# 2     63      66     82

# %%
#对df的每一行数据应用匿名函数进行计算，匿名函数实现对每一行数据的最大值与最小值计算
df.apply(lambda e:e.max()-e.min(),axis=1)
# Out:
# 0    20
# 1    12
# 2    19
# dtype: int64

# %%
# ?df.apply

# %%
#对df的每一列数据应用匿名函数进行计算，匿名函数实现对每一列数据的最大值与最小值计算
df.apply(lambda e:e.max()-e.min())
# Out:
# First     20
# Second    13
# Third     32
# dtype: int64

# %%
#%ls Data

import pandas
df = pandas.read_excel('house_sample.xlsx')
df.head()
# Out:
#                                标题    建筑面积   总价        户型  朝向      物 业 费  \
# 0    资深经纪上海人：稀缺3房，南北通透采光好，房东急需用钱！  123.50  760  3室2厅0厨2卫  南北  1.5元/平米・月
# 1     未来规划小上海，精装带地暖，养老，亲子，旅游度假一体化   86.00   76  2室2厅1厨1卫  南北    1.8元/・月
# 2      双高铁 不限贷 买一层送一层 送大露台 看房专车接送   90.00   80  3室2厅1厨2卫  南北       暂无资料
# 3      坐拥嘉兴海宁双轨 享受市区配套 现房值得拥有 可落户   90.00   80  2室1厅1厨1卫  南北       暂无资料
# 4  对口明强校区，精装两房税费少，位置安静，媲美园艺新村，随时看   66.61  285  2室1厅1厨1卫   南  0.8元/平米・月
#
#      环比上月          张贴日期  产权性质    装修  楼层
# 0  ↑1.44%  西元2017年4月12日   商品房  豪华装修  低层
# 1  ↑4.08%  西元2017年4月13日   商品房   精装修  中层
# 2  ↓0.01%  西元2017年4月14日   商品房   精装修  高层
# 3  ↓0.01%  西元2017年4月15日   商品房   简装修  中层
# 4  ↓2.62%  西元2017年4月16日  个人产权   中装修  低层

# %%
import numpy as np
def convertNaN(e):
    if e == '暂无资料':
        return np.nan
    else:
        return e
    
#将函数convertNaN应用到df的每个数据元素上
df.applymap(convertNaN)
# Out:
#                                   标题    建筑面积   总价        户型  朝向       物 业 费  \
# 0       资深经纪上海人：稀缺3房，南北通透采光好，房东急需用钱！  123.50  760  3室2厅0厨2卫  南北   1.5元/平米・月
# 1        未来规划小上海，精装带地暖，养老，亲子，旅游度假一体化   86.00   76  2室2厅1厨1卫  南北     1.8元/・月
# 2         双高铁 不限贷 买一层送一层 送大露台 看房专车接送   90.00   80  3室2厅1厨2卫  南北         NaN
# 3         坐拥嘉兴海宁双轨 享受市区配套 现房值得拥有 可落户   90.00   80  2室1厅1厨1卫  南北         NaN
# 4     对口明强校区，精装两房税费少，位置安静，媲美园艺新村，随时看   66.61  285  2室1厅1厨1卫   南   0.8元/平米・月
# 5     精装三房，精装修全送， 边套全明，小区中心位置，采光无遮挡！   72.00  295  3室1厅1厨1卫  南北   0.6元/平米・月
# 6   精装两年 楼下有固定车位 接受置换 中间楼层 双南户型 底价诚售   65.58  240  2室1厅1厨1卫   南   0.6元/平米・月
# 7              此房2楼的 房东价格可谈 价格真实产权清晰   73.35  410  3室1厅1厨1卫   南   1.4元/平米・月
# 8        浦发绿城靠近11号线 浦三路站 400万 2房2厅1卫   72.93  400  2室2厅1厨1卫   南  0.55元/平米・月
# 9        长桥六村！一房一厅户型正气南北通透！对口实验小学！好房   47.00  270  1室1厅1厨1卫  南北         NaN
# 10            此房6楼的 房东价格可谈 价格真实 诚意出售   48.55  300  2室1厅1厨1卫  南北   1.4元/平米・月
# ...

# %%
#以匿名函数形式将函数套用到df的每个数据元素上
df.applymap(lambda e:np.nan if e =='暂无资料' else e)
# Out:
#                                   标题    建筑面积   总价        户型  朝向       物 业 费  \
# 0       资深经纪上海人：稀缺3房，南北通透采光好，房东急需用钱！  123.50  760  3室2厅0厨2卫  南北   1.5元/平米・月
# 1        未来规划小上海，精装带地暖，养老，亲子，旅游度假一体化   86.00   76  2室2厅1厨1卫  南北     1.8元/・月
# 2         双高铁 不限贷 买一层送一层 送大露台 看房专车接送   90.00   80  3室2厅1厨2卫  南北         NaN
# 3         坐拥嘉兴海宁双轨 享受市区配套 现房值得拥有 可落户   90.00   80  2室1厅1厨1卫  南北         NaN
# 4     对口明强校区，精装两房税费少，位置安静，媲美园艺新村，随时看   66.61  285  2室1厅1厨1卫   南   0.8元/平米・月
# 5     精装三房，精装修全送， 边套全明，小区中心位置，采光无遮挡！   72.00  295  3室1厅1厨1卫  南北   0.6元/平米・月
# 6   精装两年 楼下有固定车位 接受置换 中间楼层 双南户型 底价诚售   65.58  240  2室1厅1厨1卫   南   0.6元/平米・月
# 7              此房2楼的 房东价格可谈 价格真实产权清晰   73.35  410  3室1厅1厨1卫   南   1.4元/平米・月
# 8        浦发绿城靠近11号线 浦三路站 400万 2房2厅1卫   72.93  400  2室2厅1厨1卫   南  0.55元/平米・月
# 9        长桥六村！一房一厅户型正气南北通透！对口实验小学！好房   47.00  270  1室1厅1厨1卫  南北         NaN
# 10            此房6楼的 房东价格可谈 价格真实 诚意出售   48.55  300  2室1厅1厨1卫  南北   1.4元/平米・月
# ...
