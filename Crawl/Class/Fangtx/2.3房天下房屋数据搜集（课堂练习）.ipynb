# %% [markdown]
# 获取房天下（上海在售二手房源相关信息）

# %%
import requests
res = requests.get('http://esf.sh.fang.com/')#获取上海在售二手房源网页首页（http://esf.sh.fang.com/）的响应包，命名为res
res.text#输出res的文本内容
# Out:
# '\r\n<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    <title>【上海二手房|上海二手房出售】_房天下买房交易平台- 上海房天下</title>\r\n    <meta http-equiv="Content-Type" content="text/html; charset=gb2312" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n    <meta http-equiv="pragma" content="no-cache" />\r\n    <meta http-equiv="Cache-Control" content="no-cache,   must-revalidate" />\r\n    <meta name="mobile-agent" content="format=html5;url=https://m.fang.com/esf/sh/">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\r\n    <meta name="renderer" content="webkit" />\r\n    <meta http-equiv="Content-Language" content="zh-cn" />\r\n    <link rel="dns-prefetch" href="//cdnsfb.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//esf.js.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//img1n.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//img11.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//js.ub.fang.com" />\r\n    <link rel="dns-prefetch" href="//mshow.fang.com" />\r\n    <link rel="dns-prefetch" href="//clickn.fang.com" />\r\n    <link rel="dns-prefetch" href="//countubn.3g.fang.com" />\r\n    <link rel="dns-prefetch" href="//countpvn.light.fang.com" />\r\n    <link rel="dns-prefetch" href="//www.google-analytics.com" />\r\n    <meta name="keywords" content="上海二手房,上海二手房出售,上海二手房买卖" />\r\n    <meta name="description" content="上海二手房9月参考均价55440元/�O,现有二手房房源515646套,房天下上海二手房网为您提供快速全面的上海二手房信息及新发布上海二手房价格，为您创造舒适二手房购房体验。" />\r\n    <meta name="location" content="province=;city=上海; " />\r\n    <link rel="stylesheet" type="text/css" href="//static.soufunimg.com/esf/esf/online/secondhouse/old/secondhouse/image/esfnew/styles/head2014/search20141022.css?v=3.2018092801" />\r\n    <meta name="applicable-device" content="mobile" />\r\n    <link rel="canonical" href="https://m.fang.com/esf/sh/" />\r\n    \r\n    <link rel="alternate" media="only screen and(max-width:640px)" href="https://m.fang.com/esf/sh/">\r\n    <link type="text/css" rel="Stylesheet" href="//static.soufunimg.com/esf/esf/online/secondhouse/esflist/static/css/SearchListHouse.css?v=3.2018092801" />\r\n\r\n    <script src="//static.soufunimg.com/common_m/pc_public/fangjs/build/jquery/jquery-1.js?3.2018092801"></script>\r\n    <script>\r\n        var pageConfig = pageConfig || {};\r\n    </script>\r\n</head>\r\n<body>\r\n    <!--首页头文件开始-->\r\n    \r\n<div>\r\n\r\n<link rel="dns-prefetch" href="//jsub.fang.com">\r\n<link rel="dns-prefetch" href="//clickm.fang.com">\r\n<link rel="dns-prefetch" href="//countubn.3g.fang.com">\r\n<link rel="dns-prefetch" href="//countpvn.3g.fang.com">\r\n<link rel="dns-prefetch" href="//static.soufunimg.com">\r\n<link rel="dns-prefetch" href="//img.soufunimg.com">\r\n<link rel="dns-prefetch" href="//imgs.soufunimg.com">\r\n<link rel="dns-prefetch" href="//img1.soufunimg.com">\r\n<link rel="dns-prefetch" href="//img1n.soufunimg.com">\r\n<link rel="dns-prefetch" href="//imgd.soufunimg.com">\r\n<link rel="dns-prefetch" href="//imgdn.soufunimg.com">\r\n<link rel="dns-prefetch" href="//img2.soufunimg.com">\r\n<link rel="dns-prefetch" href="//img2s.soufunimg.com">\r\n<link rel="dns-prefetch" href="//flvn.soufunimg.com">\r\n<link rel="dns-prefetch" href="//flvs.soufunimg.com">\r\n<link rel="dns-prefetch" href="//video2n.soufunimg.com">\r\n<link rel="dns-prefetch" href="//video2s.soufunimg.com">\r\n<link rel="dns-prefetch" href="//ssl.google-analytics.com">\r\n<link href="//static.soufunimg.com/navigation/style/navigation20141112.css" rel="stylesheet" type="text/css" />\r\n<link href="//static.soufunimg.com/homepage/new/family/css/navsupply.css" rel="stylesheet" type="text/css" />\r\n<!-- 新导航0903 begin -->\r\n\r\n<div class="newnav20141104">\r\n\t<div class="newnav20141104nr">\r\n\t\r\n\t\t<div class="s1"><a href="http://www.fang.com/"><img src="//static.soufunimg.com/navigation/images/navlogo.gif"></a></div>\r\n\t\t\r\n\t\t\r\n\t\t\t\t<div class="s2"  onMouseOver="this.className=\'s2 on2014\'" onMouseOut= ...

# %% [markdown]
# 以下代码尝试获取每套房源的详细内容页

# %%
from bs4 import BeautifulSoup
domain = 'http://esf.sh.fang.com' #将上海在售二手房源网页首页url（http://esf.sh.fang.com/）赋值给domain
soup = BeautifulSoup(res.text,'html.parser')#创建BeautifulSoup对象对res响应包进行解析，结果命名为soup
for house in soup.select('.shop_list dl dd h4 a'):#循环遍历获取网页首页所有房源详细内容页的url,循环变量名为house（提示：检查定位路径定位查找的节点是否为空）
    if house: #（提示：如果存在返回的标签节点有空的情况，需要进行判断！）
            print(domain+house['href'])#利用domain与存储房屋详细内容的相对url的标签节点构建房屋的url
            #打印输出查看url
            print('========================')#输出======表示间隔
# Out:
# http://esf.sh.fang.com/chushou/10_332231157.htm
# ========================
# http://esf.sh.fang.com/chushou/10_333208591.htm
# ========================
# http://esf.sh.fang.com/chushou/10_333135050.htm
# ========================
# http://esf.sh.fang.com/chushou/10_330019019.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332490412.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332561081.htm
# ========================
# http://esf.sh.fang.com/chushou/10_331980682.htm
# ========================
# http://esf.sh.fang.com/chushou/10_331592802.htm
# ========================
# http://esf.sh.fang.com/chushou/10_332135105.htm
# ========================
# http://esf.sh.fang.com/chushou/10_332445812.htm
# ========================
# http://esf.sh.fang.com/chushou/10_332291807.htm
# ========================
# http://esf.sh.fang.com/chushou/3_330817911.htm
# ========================
# http://esf.sh.fang.com/chushou/3_321499253.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332528963.htm
# ========================
# http://esf.sh.fang.com/chushou/3_331132340.htm
# ========================
# http://esf.sh.fang.com/chushou/3_330291111.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332771876.htm
# ========================
# http://esf.sh.fang.com/chushou/3_331740983.htm
# ========================
# http://esf.sh.fang.com/chushou/3_330661129.htm
# ========================
# http://esf.sh.fang.com/chushou/10_331817523.htm
# ========================
# http://esf.sh.fang.com/chushou/3_333275346.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332516477.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332529755.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332633378.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332886052.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332671123.htm
# ========================
# http://esf.sh.fang.com/chushou/3_331671241.htm
# ========================
# http://esf.sh.fang.com/chushou/3_333195511.htm
# ========================
# http://esf.sh.fang.com/chushou/3_333002999.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332876639.htm
# ========================
# http://esf.sh.fang.com/chushou/10_332936802.htm
# ========================
# http://esf.sh.fang.com/chushou/3_330258727.htm
# ========================
# http://esf.sh.fang.com/chushou/3_333035420.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332752632.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332222673.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332896088.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332608466.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332919923.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332863551.htm
# ========================
# http://esf.sh.fang.com/chushou/3_331279899.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332506618.htm
# ========================
# http://esf.sh.fang.com/chushou/10_333003462.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332628807.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332610582.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332315706.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332986201.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332498005.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332769982.htm
# ========================
# http://esf.sh.fang.com/chushou/3_333300445.htm
# ========================
# http://esf.sh.fang.com/chushou/3_330173773.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332862582.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332949023.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332275054.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332104104.htm
# ========================
# http://esf.sh.fang.com/chushou/3_329492655.htm
# ========================
# http://esf.sh.fang.com/chushou/3_333126005.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332581933.htm
# ========================
# http://esf.sh.fang.com/chushou/3_333262472.htm
# ========================
# http://esf.sh.fang.com/chushou/3_333012521.htm
# ========================
# http://esf.sh.fang.com/chushou/10_330959019.htm
# ========================
# http://esf.sh.fang.com/chushou/3_333257467.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332623193.htm
# ========================
# http://esf.sh.fang.com/chushou/10_332833342.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332362916.htm
# ========================
# http://esf.sh.fang.com/chushou/3_331876564.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332096687.htm
# ========================
# http://esf.sh.fang.com/chushou/3_331614818.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332012690.htm
# ========================
# http://esf.sh.fang.com/chushou/3_329564318.htm
# ========================
# http://esf.sh.fang.com/chushou/3_332072118.htm
# ========================

# %% [markdown]
# 以下代码模块将上面获取到的其中一房源的详细内容页的url进行请求并解析提取相关数据

# %%
import requests
from bs4 import BeautifulSoup
res =requests.get('http://esf.sh.fang.com/chushou/3_331876564.htm')#将以上获得的第一个房源的详细内容页进行请求访问
soup = BeautifulSoup(res.text,'html.parser')#对响应包res的网页文本进行解析，解析结果命名为soup
res.text
# Out:
# '\r\n\r\n<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    <title>15号线华泾站，正南一房，全明，总价低，上海徐汇华泾华泾五村二手房一室 - 房天下</title>\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\r\n    <meta name="renderer" content="webkit" />\r\n    <link rel="dns-prefetch" href="//cdnsfb.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//esf.js.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//img1n.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//img11.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//js.ub.fang.com" />\r\n    <link rel="dns-prefetch" href="//mshow.fang.com" />\r\n    <link rel="dns-prefetch" href="//clickn.fang.com" />\r\n    <link rel="dns-prefetch" href="//countubn.3g.fang.com" />\r\n    <link rel="dns-prefetch" href="//countpvn.light.fang.com" />\r\n    <link rel="dns-prefetch" href="//www.google-analytics.com" />\r\n    <meta name="mobile-agent" content="format=html5;url=https://m.fang.com/esf/sh/AGT_331876564.html">\r\n    <link rel="alternate" media="only screen and(max-width:640px)" href="https://m.fang.com/esf/sh/AGT_331876564.html">\r\n    <meta name="keywords" content="上海二手房出售,华泾五村二手房,一室一厅一卫一厨 二手房" />\r\n    <meta name="Description" content="上海房天下为您提供上海华泾五村二手房最新出售信息，华泾五村位于华泾路1000弄，一室一厅一卫，49.52平米，43417元/平米。想了解更多上海华泾五村二手房详细信息，请关注上海房天下二手房频道。" />\r\n    <meta http-equiv="Content-Language" content="zh-cn" />\r\n    <link href="http://esf.js.soufunimg.com/esf/esf/online/secondhouse/details/static/css/common.css?v=3.2018091802" rel="stylesheet" />\r\n    <link href="http://esf.js.soufunimg.com/esf/esf/online/secondhouse/details/static/css/detail_esfnew.css?v=3.2018091802" rel="stylesheet" />\r\n        <script type="text/javascript" src="//static.soufunimg.com/common_m/pc_public/fangjs/build/ie8/ie8.js?v=3.2018091802"></script>\r\n        <script type="text/javascript" src="//static.soufunimg.com/common_m/pc_public/fangjs/build/imgerr/imgerr.js"></script>\r\n        <script type="text/javascript" src="//static.soufunimg.com/common_m/pc_public/fangjs/build/??fang2.3.2.js,jquery/jquery-3.js?v=3.2018091802"></script>\r\n    <script>\r\n        var pageConfig = pageConfig || {};\r\n        fang.config({\r\n            base:\'http://esf.js.soufunimg.com/esf/esf/online/secondhouse/details/static/js/\',\r\n            ver: /test/.test(pageConfig.public) ? Math.random().toString(32).substring(2) : \'3.2018091802\'\r\n        });\r\n    </script>\r\n</head>\r\n<body style="overflow-x:hidden ">\r\n    \r\n    <!--首页头文件开始-->\r\n    \r\n\r\n    <div id="agantesfxq_B01_01">\r\n    \r\n\r\n<link rel="dns-prefetch" href="//jsub.fang.com">\r\n<link rel="dns-prefetch" href="//clickm.fang.com">\r\n<link rel="dns-prefetch" href="//countubn.3g.fang.com">\r\n<link rel="dns-prefetch" href="//countpvn.3g.fang.com">\r\n<link rel="dns-prefetch" href="//static.soufunimg.com">\r\n<link rel="dns-prefetch" href="//img.soufunimg.com">\r\n<link rel="dns-prefetch" href="//imgs.soufunimg.com">\r\n<link rel="dns-prefetch" href="//img1.soufunimg.com">\r\n<link rel="dns-prefetch" href="//img1n.soufunimg.com">\r\n<link rel="dns-prefetch" href="//imgd.soufunimg.com">\r\n<link rel="dns-prefetch" href="//imgdn.soufunimg.com">\r\n<link rel="dns-prefetch" href="//img2.soufunimg.com">\r\n<link rel="dns-prefetch" href="//img2s.soufunimg.com">\r\n<link rel="dns-prefetch" href="//flvn.soufunimg.com">\r\n<link rel="dns-prefetch" href="//flvs.soufunimg.com">\r\n<link rel="dns-prefetch" href="//video2n.soufunimg.com">\r\n<link rel="dns-prefetch" href="//video2s.soufunimg.com">\r\n<link rel="dns-prefetch" href="//ssl.google-analytics.com">\r\n<link href="//static.soufunimg.com/navigation/style/navigation20141112.css" rel="stylesheet" type="text/css" />\r\n<link href="//static.soufunimg.com/homepage/new/family/css/navsupply.css" rel="stylesheet" type="text/css" />\r\n<!-- 新导航0903 begin -->\r\n\r\n<div class="newnav20141104">\r\n\t<div class="newnav20141104nr">\r\n\t\r\n\t\t<div class="s1"><a href="http://www.fang.com/"><img src="//stat ...

# %%
info ={}#定义字典变量info，用于存放每套房子相关数据
info['标题']=soup.select('.title h1')[0].text.strip()#查找房子标题，以“标题”为key名存入info
info#查看info
# Out:
# {'标题': '15号线华泾站，正南一房，全明，总价低'}

# %%
info['总价']=soup.select('.price_esf')[0].text#查找总价，以“总价”为key名存入info
info#查看info
# Out:
# {'标题': '15号线华泾站，正南一房，全明，总价低', '总价': '215万'}

# %%
k=['总价','单价','建筑面积','朝向','楼层','装修','户型','标题']
for item in soup.select('.trl-item1'):#item表示包括户型，朝向，单价，楼层，装修等相关数据的标签，思考：观察这些数据都在哪个标签下？
     key=item.select('.font14')[0].text.strip()
     value=item.select('.tt')[0].text.strip()   
            #key计划用于表示房屋的字段，问，key在哪个标签节点？这些key作为字段，有没有问题
            #value计划用于表示房屋相关字段对应数
     info[key]=value
print(info)
print(list(info.values()))
print(k)
print(dict(zip(k,list(info.values()))))
# Out:
# {'标题': '15号线华泾站，正南一房，全明，总价低', '总价': '215万', '户型': '1室1厅1卫', '建筑面积': '49.52平米', '单价': '43417元/平米', '朝向': '南', '楼层（共6层）': '高层', '装修': '中装修'}
# ['15号线华泾站，正南一房，全明，总价低', '215万', '1室1厅1卫', '49.52平米', '43417元/平米', '南', '高层', '中装修']
# ['总价', '单价', '建筑面积', '朝向', '楼层', '装修', '户型', '标题']
# {'总价': '15号线华泾站，正南一房，全明，总价低', '单价': '215万', '建筑面积': '1室1厅1卫', '朝向': '49.52平米', '楼层': '43417元/平米', '装修': '南', '户型': '高层', '标题': '中装修'}

# %% [markdown]
# 根据上面分析定义一个获取网页详细内容页的函数getHouseDetail

# %%
def getHouseDetail(url):
    info={}
    info_adj={}
    res=requests.get(url)#根据url请求网页内容
    soup = BeautifulSoup(res.text,'html.parser')#解析详细内容页，结果命名为soup
    info['标题']=soup.select('.title h1')[0].text.strip()#获取房屋名并加入info字典，key值命名为“标题
    info['总价']=soup.select('.price_esf')[0].text#获取房屋总价并加入info字典，key值命名为“总价
    for item in soup.select('.trl-item1'):#用item做为循环变量名，代表当前网页class为trl-item1的所有标签节点
        key=item.select('.font14')[0].text.strip()#key表示item标签下所有class为font14的标签节点文本内容
        #print(key)
        value=item.select('.tt')[0].text.strip()  #value示item标签下所有class为tt的标签节点文本内容
        info[key]=value   #将info里面所有key赋值给value
        k=['总价','单价','建筑面积','朝向','楼层','装修','户型','标题']      
    info_adj=dict(zip(k,list(info.values())))
    #print(info_adj)
    return info_adj

# %%
getHouseDetail('http://esf.sh.fang.com/chushou/3_328597533.htm')
# Out:
# {'总价': '精装修，近3号大柏树站，品质小区，素质住户！',
#  '单价': '358万',
#  '建筑面积': '2室1厅1卫',
#  '朝向': '68.2平米',
#  '楼层': '52493元/平米',
#  '装修': '南',
#  '户型': '中层',
#  '标题': '精装修'}

# %% [markdown]
# 以下代码模块通过获取所有房屋的详细内容页url，获取每一房屋的相关字段信息

# %%
import requests
from bs4 import BeautifulSoup
houseary=[]#定义列表用于存储所有房屋的相关数据
domain='http://esf.sh.fang.com'#domain为http://esf.sh.fang.com域名
res=requests.get('http://esf.sh.fang.com')#请求访问http://esf.sh.fang.com首页，获得响应包res
soup=BeautifulSoup(res.text,'html.parser')#创建BeatifulSoup对象并进行解析
for link in soup.select('.shop_list dl dd h4 a'):#循环遍历获取网页首页中存有的标签节点，循环变量命名为link
    url=domain+link['href']#利用domain与存储房屋详细内容的相对url的标签节点构建房屋的url
