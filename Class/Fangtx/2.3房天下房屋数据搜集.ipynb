# %% [markdown]
# 获取房天下（上海在售二手房源相关信息）

# %%
import requests
res = requests.get('http://esf.sh.fang.com/')#获取上海在售二手房源网页首页（http://esf.sh.fang.com/）的响应包，命名为res
res.text#输出res的文本内容
# Out:
# '\r\n<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    <title>【上海二手房|上海二手房出售】_房天下买房交易平台- 上海房天下</title>\r\n    <meta http-equiv="Content-Type" content="text/html; charset=gb2312" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n    <meta http-equiv="pragma" content="no-cache" />\r\n    <meta http-equiv="Cache-Control" content="no-cache,   must-revalidate" />\r\n    <meta name="mobile-agent" content="format=html5;url=https://m.fang.com/esf/sh/">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\r\n    <meta name="renderer" content="webkit" />\r\n    <meta http-equiv="Content-Language" content="zh-cn" />\r\n    <link rel="dns-prefetch" href="//cdnsfb.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//esf.js.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//img1n.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//img11.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//js.ub.fang.com" />\r\n    <link rel="dns-
# ...

# %% [markdown]
# 以下代码尝试获取每套房源的详细内容页

# %%
from bs4 import BeautifulSoup
domain = 'http://esf.sh.fang.com/' #将上海在售二手房源网页首页url（http://esf.sh.fang.com/）赋值给domain
soup = BeautifulSoup(res.text,'html.parser')#创建BeautifulSoup对象对res响应包进行解析，结果命名为soup
for house in soup.select('.shop_list dl dd h4 a'):#循环遍历获取网页首页所有房源详细内容页的url,循环变量名为house（提示：检查定位路径定位查找的节点是否为空）
    if house: #（提示：如果存在返回的标签节点有空的情况，需要进行判断！）
            print(domain+house['href'])#利用domain与存储房屋详细内容的相对url的标签节点构建房屋的url
            #打印输出查看url
            print('========================')#输出======表示间隔
# Out:
# http://esf.sh.fang.com//chushou/3_332585904.htm
# ...
# http://esf.sh.fang.com//chushou/3_332821401.htm
# ...
# http://esf.sh.fang.com//chushou/3_332567614.htm
# ...
# http://esf.sh.fang.com//chushou/3_331620333.htm
# ...
# http://esf.sh.fang.com//chushou/3_326023893.htm
# ...
# http://esf.sh.fang.com//chushou/10_331949570.htm
# ...
# http://esf.sh.fang.com//chushou/3_332384428.htm
# ...
# http://esf.sh.fang.com//chushou/10_332328956.htm
# ...
# http://esf.sh.fang.com//chushou/3_329527370.htm
# ...
# http://esf.sh.fang.com//chushou/3_332818417.htm
# ...
# http://esf.sh.fang.com//chushou/3_329537783.htm
# ...
# http://esf.sh.fang.com//chushou/10_332141145.htm
# ...
# http://esf.sh.fang.com//chushou/10_332475399.htm
# ...
# http://esf.sh.fang.com//chushou/3_316692427.htm
# ...
# http://esf.sh.fang.com//chushou/3_329737046.htm
# ...
# http://esf.sh.fang.com//chushou/3_332361922.htm
# ...
# http://esf.sh.fang.com//chushou/3_332596154.htm
# ...
# http://esf.sh.fang.com//chushou/3_320398056.htm
# ...
# http://esf.sh.fang.com//chushou/10_327676971.htm
# ...

# %% [markdown]
# 以下代码模块将上面获取到的其中一房源的详细内容页的url进行请求并解析提取相关数据

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('http://esf.sh.fang.com//chushou/3_330177402.htm')#将以上获得的第一个房源的详细内容页进行请求访问
soup = BeautifulSoup(res.text,'html.parser')#对响应包res的网页文本进行解析，解析结果命名为soup
res.text
# Out:
# '\r\n\r\n<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    <title>瑞嘉苑，近410双轨交通，南北通2房，低于市场价，精装修急，上海虹口四川北路瑞嘉苑二手房两室 - 房天下</title>\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\r\n    <meta name="renderer" content="webkit" />\r\n    <link rel="dns-prefetch" href="//cdnsfb.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//esf.js.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//img1n.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//img11.soufunimg.com" />\r\n    <link rel="dns-prefetch" href="//js.ub.fang.com" />\r\n    <link rel="dns-prefetch" href="//mshow.fang.com" />\r\n    <link rel="dns-prefetch" href="//clickn.fang.com" />\r\n    <link rel="dns-prefetch" href="//countubn.3g.fang.com" />\r\n    <link rel="dns-prefetch" href="//countpvn.light.fang.com" />\r\n    <link rel="dns-prefetch" href="//www.google-analytics.com" />\r\n    <meta name="mobile-agent" content="format=html5;url=https://m.fang.com/esf/sh/AGT_330177402.html">\r\n    <link 
# ...

# %%
info ={}#定义字典变量info，用于存放每套房子相关数据
info['标题'] = soup.select('.title h1')[0].text.strip()#查找房子标题，以“标题”为key名存入info
info#查看info
# Out:
# {'标题': '瑞嘉苑，近410双轨交通，南北通2房，低于市场价，精装修急'}

# %%
info['总价']=soup.select('.price_esf')[0].text#查找总价，以“总价”为key名存入info
info#查看info
# Out:
# {'总价': '860万', '标题': '瑞嘉苑，近410双轨交通，南北通2房，低于市场价，精装修急'}

# %%
k=['总价','单价','建筑面积','朝向','楼层','装修','户型','标题']
for item in soup.select('.trl-item1'):#item表示包括户型，朝向，单价，楼层，装修等相关数据的标签，思考：观察这些数据都在哪个标签下？
     key=item.select('.font14')[0].text.strip()
     value=item.select('.tt')[0].text.strip()   
            #key计划用于表示房屋的字段，问，key在哪个标签节点？这些key作为字段，有没有问题
            #value计划用于表示房屋相关字段对应数
     info[key]=value
print(info)
print(list(info.values()))
print(k)
print(dict(zip(k,list(info.values()))))
# Out:
# {'标题': '瑞嘉苑，近410双轨交通，南北通2房，低于市场价，精装修急', '总价': '860万', '户型': '2室2厅2卫', '建筑面积': '130平米', '单价': '66154元/平米', '朝向': '南北', '楼层（共29层）': '中层', '装修': '精装修'}
# ['瑞嘉苑，近410双轨交通，南北通2房，低于市场价，精装修急', '860万', '2室2厅2卫', '130平米', '66154元/平米', '南北', '中层', '精装修']
# ['总价', '单价', '建筑面积', '朝向', '楼层', '装修', '户型', '标题']
# {'总价': '瑞嘉苑，近410双轨交通，南北通2房，低于市场价，精装修急', '单价': '860万', '建筑面积': '2室2厅2卫', '朝向': '130平米', '楼层': '66154元/平米', '装修': '南北', '户型': '中层', '标题': '精装修'}

# %% [markdown]
# 根据上面分析定义一个获取网页详细内容页的函数getHouseDetail

# %%
def getHouseDetail(url):
    info={}
    info_adj={}
    res=requests.get(url)#根据url请求网页内容
    soup = BeautifulSoup(res.text,'html.parser')#解析详细内容页，结果命名为soup
    info['标题']=soup.select('.title h1')[0].text.strip()#获取房屋名并加入info字典，key值命名为“标题
    info['总价']=soup.select('.price_esf')[0].text#获取房屋总价并加入info字典，key值命名为“总价
    for item in soup.select('.trl-item1'):#用item做为循环变量名，代表当前网页class为trl-item1的所有标签节点
        key=item.select('.font14')[0].text.strip()#key表示item标签下所有class为font14的标签节点文本内容
        #print(key)
        value=item.select('.tt')[0].text.strip()  #value示item标签下所有class为tt的标签节点文本内容
        info[key]=value   #将info里面所有key赋值给value
        k=['总价','单价','建筑面积','朝向','楼层','装修','户型','标题']      
    info_adj=dict(zip(k,list(info.values())))
    #print(info_adj)
    return info_adj

# %%
getHouseDetail('http://esf.sh.fang.com/chushou/3_328597533.htm')
# Out:
# {'总价': '精装修，近3号大柏树站，品质小区，素质住户！', '单价': '358万', '建筑面积': '2室1厅1卫', '朝向': '68.2平米', '楼层': '52493元/平米', '装修': '南', '户型': '中层', '标题': '精装修'}

# %% [markdown]
# 以下代码模块通过获取所有房屋的详细内容页url，获取每一房屋的相关字段信息

# %%
import requests
from bs4 import BeautifulSoup
houseary=[]#定义列表用于存储所有房屋的相关数据
domain='http://esf.sh.fang.com'#domain为http://esf.sh.fang.com域名
res=requests.get('http://esf.sh.fang.com')#请求访问http://esf.sh.fang.com首页，获得响应包res
soup=BeautifulSoup(res.text,'html.parser')#创建BeatifulSoup对象并进行解析
for link in soup.select('.shop_list dl dd h4 a'):#循环遍历获取网页首页中存有的标签节点，循环变量命名为link
    url=domain+link['href']#利用domain与存储房屋详细内容的相对url的标签节点构建房屋的url
    houseary.append(getHouseDetail(url))#调用getHouseDetail函数获取每一房屋相关数据并追加到houseary

# %%
len(houseary)#求总共获取到多少套房屋信息
# Out:
# 70

# %%
import pandas
df = pandas.DataFrame(houseary)#将获取到的所有房屋信息转换成数据框的结构
df
# Out:
#          单价    建筑面积                                    总价  户型        朝向    标题  \
# 0     1000万  2室2厅2卫               水清木华，景观好，楼层好，超低市场价，三天必卖  高层     118平米   精装修
# 1     1020万  3室2厅2卫              品质森兰，近轨道交通， 业主，接受置换，价格可谈  低层  151.59平米   精装修
# 2     1000万  2室2厅2卫             水清木华,精致朝南2居室,联洋商圈中间位置看房方便  高层     116平米   精装修
# 3     2250万  5室2厅6卫       （必卖房）御涛园 此房由我司帮业主购进 诚意出售 东南双面邻水  低层     529平米  豪华装修
# 4     1100万  3室2厅2卫               业主诚心出售 周边配套齐全 交通便利 看房方便  高层     137平米   精装修
# 5     1060万  2室2厅1卫             开发商保留 不 近地铁 一梯一户 通煤气 拎包入住  中层     158平米   精装修
# 6     1450万  3室2厅2卫                   高区正气三房，满五年，保养好，看房方便  中层     144平米   精装修
# 7     1600万  4室2厅3卫            仁恒品质！二期新出高区景观房！看房有钥匙！业主出国！  高层     214平米  豪华装修
# 8     5000万  5室2厅4卫          5000万可买双八角窗三卧客厅朝南，看房方便，满五税费少  低层     486平米  豪华装修
# 9     3730万  3室2厅3卫         碧云全新獨栋丨下沉式庭院丨德系环保材料丨报价比肩同户型成交  低层     435平米   精装修
# 10   690.5万  3室2厅2卫         业主置换 直击底价 前滩一路之隔高品质小区 南北通透带车位  中层     138平米  豪华装修
# ...

# %%
df.to_excel('house.xlsx')#存储到当前工作空间目录下，文件命名为house.xlsx
